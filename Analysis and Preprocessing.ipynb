# %% [markdown]
# # **Higgs Boson Signal Process Discrimination**
# # 1. Analysis and Preprocessing

# %% [markdown]
# This notebook contains the data analysis and preprocessing applied to the dataset used in the implementation of a GPU-based machine learning technique for discriminating between a signal process that produces Higgs bosons and a background process that does not.

# %%
import cudf
import pandas as pd
import cupy as cp
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import time

import warnings
warnings.filterwarnings('ignore')
matplotlib.use("Agg")
%matplotlib inline

# %% [markdown]
# ----
# ## 1.1 Exploratory Data Analysis (EDA)

# %% [markdown]
# For this study, the [UCI Higgs dataset](https://archive.ics.uci.edu/ml/datasets/HIGGS) will be used for training and testing. This dataset aims to aid in solving the classification problem that distinguishes between a signal process responsible for producing Higgs bosons and a background process that does not. The objective of the dataset is to explore the use of deep learning methods to automate the feature engineering process currently performed manually by physicists. <br/><br/>
# The dataset is comprised of 11 million instances generated via Monte Carlo simulations. Each instance is represented by 29 features.

# %%
df = cudf.read_csv('./Partical.csv')
print('data shape:',df.shape)
# Out:
# data shape: (10999999, 29)

# %% [markdown]
# The first feature serves as a binary label feature, with 1 signifying a signal process and 0 for a background process. The following 21 features are low-level features representing kinematic properties. Those features are measured by particle detectors. The remaining seven features are high-level features. High-level features are manually devised by physicists to discriminate between the processes.

# %%
columns = ['process', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b_tag', 'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b_tag', 'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b_tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b_tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']
df.columns = columns

# %%
'''
This copy of the dataset is saved in pandas only to be used with plotting libraries such as matplotlib and seaborn.
This will facilitate the EDA stage.
The pandas copy will NOT be used in training, validation or testing.
'''
df_pandas = df.to_pandas()

# %%
df.head()
# Out:
#    process  lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0      1.0   0.907542    0.329147    0.359412                  1.497970
# 1      1.0   0.798835    1.470639   -1.635975                  0.453773
# 2      0.0   1.344385   -0.876626    0.935913                  1.992050
# 3      1.0   1.105009    0.321356    1.522401                  0.882808
# 4      0.0   1.595839   -0.607811    0.007075                  1.818450
#
#    missing_energy_phi  jet_1_pt  jet_1_eta  jet_1_phi  jet_1_b_tag  ...  \
# 0           -0.313010  1.095531  -0.557525  -1.588230     2.173076  ...
# 1            0.425629  1.104875   1.282322   1.381664     0.000000  ...
# 2            0.882454  1.786066  -1.646778  -0.942383     0.000000  ...
# 3           -1.205349  0.681466  -1.070464  -0.921871     0.000000  ...
# 4           -0.111906  0.847550  -0.566437   1.581239     2.173076  ...
#
#    jet_4_eta  jet_4_phi  jet_4_b_tag      m_jj     m_jjj      m_lv     m_jlv  \
# 0  -1.138930  -0.000819     0.000000  0.302220  0.833048  0.985700  0.978098
# 1   1.128848   0.900461     0.000000  0.909753  1.108330  0.985692  0.951331
# 2  -0.678379  -1.360356     0.000000  0.946652  1.028704  0.998656  0.728281
# 3  -0.373566   0.113041     0.000000  0.755856  1.361057  0.986610  0.838085
# 4  -0.654227  -1.274345     3.101961  0.823761  0.938191  0.971758  0.789176
#
#        m_bb     m_wbb    m_wwbb
# 0  0.779732  0.992356  0.798343
# 1  0.803252  0.865924  0.780118
# 2  0.869200  1.026736  0.957904
# 3  1.133295  0.872245  0.808487
# 4  0.430553  0.961357  0.957818
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#             process     lepton_pT    lepton_eta    lepton_phi  \
# count  1.100000e+07  1.100000e+07  1.100000e+07  1.100000e+07
# mean   5.299200e-01  9.914660e-01 -8.000000e-06 -1.300000e-05
# std    4.991040e-01  5.653780e-01  1.008827e+00  1.006346e+00
# min    0.000000e+00  2.746970e-01 -2.434976e+00 -1.742508e+00
# 25%    0.000000e+00  5.907530e-01 -7.383220e-01 -8.719310e-01
# 50%    1.000000e+00  8.533710e-01 -5.400000e-05 -2.410000e-04
# 75%    1.000000e+00  1.236226e+00  7.382140e-01  8.709940e-01
# max    1.000000e+00  1.209891e+01  2.434868e+00  1.743236e+00
#
#        missing_energy_magnitude  missing_energy_phi      jet_1_pt  \
# count              1.100000e+07        1.100000e+07  1.100000e+07
# mean               9.985360e-01        2.600000e-05  9.909150e-01
# std                6.000180e-01        1.006326e+00  4.749750e-01
# min                2.370000e-04       -1.743944e+00  1.375020e-01
# 25%                5.768160e-01       -8.712080e-01  6.789930e-01
# 50%                8.916280e-01        2.130000e-04  8.948190e-01
# 75%                1.293056e+00        8.714710e-01  1.170740e+00
# max                1.539682e+01        1.743257e+00  9.940391e+00
#
#           jet_1_eta     jet_1_phi   jet_1_b_tag  ...     jet_4_eta  \
# count  1.100000e+07  1.100000e+07  1.100000e+07  ...  1.100000e+07
# mean  -2.000000e-05  8.000000e-06  9.999690e-01  ... -6.000000e-06
# std    1.009303e+00  1.005901e+00  1.027808e+00  ...  1.007694e+00
# min   -2.969725e+00 -1.741237e+00  0.000000e+00  ... -2.497265e+00
# 25%   -6.872450e-01 -8.680960e-01  0.000000e+00  ... -7.141900e-01
# 50%   -2.500000e-05  5.800000e-05  1.086538e+00  ...  3.720000e-04
# 75%    6.871940e-01  8.683130e-01  2.173076e+00  ...  7.141020e-01
# max    2.969674e+00  1.741454e+00  2.173076e+00  ...  2.498009e+00
#
#           jet_4_phi   jet_4_b_tag          m_jj         m_jjj          m_lv  \
# count  1.100000e+07  1.100000e+07  1.100000e+07  1.100000e+07  1.100000e+07
# mean   1.700000e-05  1.000000e+00  1.034290e+00  1.024805e+00  1.050554e+00
# std    1.006366e+00  1.400209e+00  6.746350e-01  3.808070e-01  1.645760e-01
# min   -1.742691e+00  0.000000e+00  7.507000e-02  1.986760e-01  8.304900e-02
# 25%   -8.714790e-01  0.000000e+00  7.906100e-01  8.462270e-01  9.857520e-01
# 50%   -2.640000e-04  0.000000e+00  8.949300e-01  9.506850e-01  9.897800e-01
# 75%    8.716050e-01  3.101961e+00  1.024730e+00  1.083493e+00  1.020528e+00
# max    1.743372e+00  3.101961e+00  4.019237e+01  2.037278e+01  7.992739e+00
#
#               m_jlv          m_bb         m_wbb        m_wwbb
# count  1.100000e+07  1.100000e+07  1.100000e+07  1.100000e+07
# mean   1.009742e+00  9.729600e-01  1.033036e+00  9.598120e-01
# std    3.974450e-01  5.254060e-01  3.652560e-01  3.133380e-01
# min    1.320060e-01  4.786200e-02  2.951120e-01  3.307210e-01
# 25%    7.675730e-01  6.738170e-01  8.193960e-01  7.703900e-01
# 50%    9.165110e-01  8.733800e-01  9.473450e-01  8.719700e-01
# 75%    1.142226e+00  1.138439e+00  1.140458e+00  1.059248e+00
# max    1.426244e+01  1.776285e+01  1.149652e+01  8.374498e+00
#
# [8 rows x 29 columns]

# %% [markdown]
# ### Missing values

# %% [markdown]
# The dataset is perfectly complete with no missing values accross all instances.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Histogram distribution

# %% [markdown]
# The following histogram plots show the distibution of each of the 28 features ignoring the label feature. The graph shows that only 5 features follow a perfect normal distribution. 6 features appear to be almost constant with a very small range of change in values. The remaining appear to be mostly skewed to the left.

# %%
df_pandas.iloc[:, 1:].hist(bins=30, figsize=(18,18));

# %% [markdown]
# ---

# %% [markdown]
# ### Class distribution

# %% [markdown]
# The next plot shows the class ditribution between the two classes. There appears to be a slight class imbalance, with 53% of the data representing the signal process and 47% representing the background process.

# %%
signal_dist = round((df.query('process == 1.00').shape[0] / df.shape[0])*100, 2)
bckgrnd_dist = 100 - signal_dist
plt.pie([signal_dist, bckgrnd_dist],labels=['signal', 'background'], startangle=90, autopct='%1.1f%%');

# %% [markdown]
# ---

# %% [markdown]
# ### Correlation

# %% [markdown]
# The following graph shows the correlation among all features. The highest correlation exists between the last two features, m_wbb and m_wwbb, with 90%. Another relatively high correlation appears between m_jj and m_jjj, with 80%. All four are high-level features. <br/> <br/>
# A correlation of 90% and 80% is considered high and suggests that the two features are closely related. Apart from these two, the remaining features do not significantly correlate with one another.

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(18, 18)
pd.options.display.max_rows = 4000

matrix = df.corr().abs().round(2)
sns.heatmap(matrix.to_cupy().get(), annot=True, cmap="crest");

# %% [markdown]
# ---

# %% [markdown]
# ### Outliers

# %% [markdown]
# By analysing the following graph, it is clear that most of the features contain a considerable number of outliers. Outliers can significantly impact the accuracy and reliability of a model. In this dataset, however, outliers comprise a large portion of the instances, making it difficult to entirely eliminate them from the dataset.

# %%
fig, ax = plt.subplots(1, 1)
sns.boxplot(data=df_pandas.drop(['process'], axis = 1))
plt.xticks(rotation=45)
fig.set_size_inches(20, 12)
fig.show()

# %% [markdown]
# ---
# ## 1.2 Data pre-processing

# %% [markdown]
# ### 1.2.1. Remove correlated feature

# %% [markdown]
# Before applying any feature engineering to the data, unnecceary data such as redundant features and outliers must be removed first. The first step is addressing correlated features.

# %% [markdown]
# **The next table shows any pair of features with a correlation above 50% is a descending order.**

# %%
corr = matrix.to_pandas().mask(np.tril(np.ones(matrix.shape)).astype(np.bool))
corr = corr[corr >= 0.5].stack().sort_values(kind="quicksort", ascending=False)
corr.reset_index()
# Out:
#   level_0 level_1     0
# 0   m_wbb  m_wwbb  0.90
# 1    m_jj   m_jjj  0.80
# 2   m_jjj   m_wbb  0.61
# 3   m_jjj  m_wwbb  0.59
# 4   m_jlv   m_wbb  0.57
# 5    m_bb   m_wbb  0.56
# 6   m_jlv  m_wwbb  0.55

# %% [markdown]
# The highest correlation appears between the pairs (m_wbb, m_wwbb) and (m_jj, m_jjj). By looking at the remaining pairs, **m_wbb** and **m_jjj** are correlated with other features more than their respective pair. <br/><br/>
# Fot this reason, **m_wbb** and **m_jjj** are discarded.

# %%
df_clean = df.drop(['m_wbb', 'm_jjj'], axis=1)
columns = [x for x in columns if x != 'm_wbb' and x != 'm_jjj']

# %% [markdown]
# ### 1.2.2. Remove outliers

# %% [markdown]
# To ensure the reliability of the data, it is essential to eliminate data outliers. To achieve this, the first quartile (q1) and third quartile (q3) are first calculated for each feature. Then, the interquartile range (IQR) is measured as the difference between both quartiles. Next, the low and high values are calculated using the following formulas:
#
#     low = q1 - 1.5*IQR               high = q3 + 1.5*IQR

# %%
def remove_outliers__col(df_in, col_name, df_out, iqr_range=1.5):
    [q1, q3] = cp.quantile(cp.asarray(df_in[col_name]), [0.25, 0.75])
    iqr = q3 - q1
    low  = q1 - (iqr_range * iqr)
    high = q3 + (iqr_range * iqr)
    df_out = df_out.query('' + col_name + ' > ' +  str(low)).query('' + col_name + ' < ' +  str(high))
    return df_out

def remove_outliers(_df, iqr_range=1.5):
    df_out = _df.copy(deep=True)
    for x in _df:
        if(x != 'process'):
            df_out = remove_outliers__col(_df, x, df_out, iqr_range)
            
    remaining = (len(df_out)/len(_df)) * 100
    print('The remaining records ammount to {}% of the original data.'.format(round(remaining, 2)))
    
    return df_out

# %%
df_clean_1 = remove_outliers(df_clean, 1.5)
# Out:
# The remaining records ammount to 53.69% of the original data.

# %% [markdown]
# The previous approach in removing the outliers resulted in the elimination of 46.31% of the dataset. This is a huge protion of valuable data, losing this much data will potentially affect the final quality of the trained models.

# %% [markdown]
# To overcome this limitation, an updated approach is used that allows eliminating extreme outliers while preserving a larger portion of the data. The formulas for the high and low ranges will be adjusted by increasing the range to 3 interquartile ranges away, resulting in the formulas:
#
#     low = q1 - 3*IQR               high = q3 + 3*IQR

# %%
df_clean_2 = remove_outliers(df_clean, 3)
# Out:
# The remaining records ammount to 74.26% of the original data.

# %% [markdown]
# This approach resulted in the elimination of 25.74% of the data. This new percentage is still significant, but it is much lower than the previous ratio, which eliminated almost half of the dataset. Despite the lost data being valuable, this step was crucial to achieve trustworthy results in the training process.

# %%
df_clean = df_clean_2
df_clean.shape
# Out:
# (8168792, 27)

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2.3. Data splitting

# %% [markdown]
# Before data resampling, normalisation and standardisation, the dataset is splitted into training, validation and test sets. This prevents the risk of data leakage. The first column is used as the label vector (y). The dataset is split into 70%, 10%, 20% for training, validation and testing, respectively.

# %%
df_feat = df_clean.drop('process', axis=1)
df_target = df_clean['process'].astype(int)

# %%
from cuml.model_selection import train_test_split

X, X_test, y, y_test = train_test_split(df_feat, df_target, test_size=0.20, random_state=101)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.10, random_state=101)

# %% [markdown]
# ### 1.2.3. Class distribution

# %% [markdown]
# After the removal of outliers, the class imbalance remains in the data with roughly the same ratio.

# %%
signal_dist = round((cudf.DataFrame(y_train).query('process == 1.00').shape[0] / y_train.shape[0])*100, 2)
bckgrnd_dist = 100 - signal_dist
plt.pie([signal_dist, bckgrnd_dist],labels=['signal', 'background'], startangle=90, autopct='%1.1f%%');

# %% [markdown]
# The SMOTE (Synthetic Minority Over-sampling Technique) algorithm will be used to oversample the background class. SMOTE is a commonly used oversampling method that generates synthetic examples of the underrepresented class by interpolating between existing samples. This effectively increases the number of minority class samples without replicating the existing ones.

# %% [markdown]
# For this task, the imbalanced-learn library is used.

# %%
!pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (from imbalanced-learn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (from imbalanced-learn) (3.0.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/msc1/anaconda3/envs/Env-7145COMP/lib/python3.7/site-packages (from imbalanced-learn) (1.7.3)

# %% [markdown]
# To accelerate the resampling process, cuML estimators can be used with imbalanced-learn to run a faster resampling [[1]](https://medium.com/rapids-ai/faster-resampling-with-imbalanced-learn-and-cuml-6cfc1dae63bf). The cuML nearest neighbors estimator will be passed to the SMOTE function wile resampling. This will result in significant acceleration for the resampling process.

# %%
from imblearn.over_sampling import SMOTE
from cuml.neighbors import NearestNeighbors
from cuml.svm import SVC
import time

start = time.time()
nn = NearestNeighbors(n_neighbors=6)
X_resampled, y_resampled = SMOTE(k_neighbors=nn).fit_resample(X_train.to_cupy().get(), y_train.to_cupy().get())
end = time.time()
print('Time passed: {} seconds.'.format(round(end - start, 2)))
# Out:
# Time passed: 87.35 seconds.

# %%
''' convert back to cudf '''
X_train = cudf.DataFrame(X_resampled, columns=columns[1:])
y_train = cudf.DataFrame(y_resampled, columns=['process'])

# %% [markdown]
# Due to the huge size of the dataset at hand, the preprocssing stage is computationally expensive and requires a long time to go through. For this reason, going forward, any extracted features or values will be exported to csv files. The exported values can then be loaded for in a later stage without the need to go through the pre-processing stage again. This will allow more freedom for experimentation in the training phase.

# %%
def export_data_sets(prefix=''):
    if prefix != '':
        prefix += '-'

    print('exporting training set...', end='');
    X_train.to_csv('./datasets/{}X_train.csv'.format(prefix), index=False)
    y_train.to_csv('./datasets/{}y_train.csv'.format(prefix), index=False)
    print('done!')
    
    print('exporting validation set...', end='');
    X_val.to_csv('./datasets/{}X_val.csv'.format(prefix), index=False)
    cudf.DataFrame(y_val, columns=['process']).to_csv('./datasets/{}y_val.csv'.format(prefix), index=False)
    print('done!')
    
    print('exporting test set...', end='');
    X_test.to_csv('./datasets/{}X_test.csv'.format(prefix), index=False)
    cudf.DataFrame(y_test, columns=['process']).to_csv('./datasets/{}y_test.csv'.format(prefix), index=False)
    print('done!')

# %% [markdown]
# The resampled data is stored on disk for future use.

# %%
export_data_sets('resampled')
# Out:
# exporting training set...done!
# exporting validation set...done!
# exporting test set...done!

# %% [markdown]
# ### 1.2.4 Normalisation

# %% [markdown]
# In order to ensure the accuracy and reliability of the trained models, it is crucial to normalise the data set. As shown in Figure 1, only five features out of 27 remaining follow a perfect normal distribution. Normalisation refers to the procedure of modifying the data such that it has a mean of zero and a standard deviation of one, thereby making it more comprehensible and comparable. The cuML normaliser will be used to normalise the whole dataset.

# %%
from cuml.preprocessing import Normalizer

normalizer = Normalizer().fit(X_train)

X_train = normalizer.transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

# %% [markdown]
# ### 1.2.5 Standardisation

# %% [markdown]
# It is also important to standardise the the data before training. The cuML MaxAbsScaler will be used to normalise the whole dataset.

# %%
from cuml.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
''' The two previous operations change the columns naming which later confuses the xgboost model.
    Thus, the columns are renamed to the original names '''
X_train.columns = columns[1:]
X_val.columns = columns[1:]
X_test.columns = columns[1:]

# %% [markdown]
# The final version of the three sets are saved to csv format for future use.

# %%
export_data_sets()
# Out:
# exporting training set...done!
# exporting validation set...done!
# exporting test set...done!

# %% [markdown]
# ## References

# %% [markdown]
# [1] Faster Resampling with Imbalanced-learn and cuML | by Nick Becker | RAPIDS AI | Feb, 2023 | Medium
# https://medium.com/rapids-ai/faster-resampling-with-imbalanced-learn-and-cuml-6cfc1dae63bf
# Accessed: 2023-04-16
